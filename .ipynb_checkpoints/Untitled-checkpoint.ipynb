# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import re

# %%
train= pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
columns_with_na = {
    'Alley': 'NoAlleyAccess',
    'GarageType': 'NoGarage',
    'GarageFinish': 'NoGarage',
    'GarageQual': 'NoGarage',
    'GarageCond': 'NoGarage',
    'BsmtQual': 'NoBasement',
    'BsmtCond': 'NoBasement',
    'BsmtExposure': 'NoBasement',
    'BsmtFinType1': 'NoBasement',
    'BsmtFinType2': 'NoBasement',
    'PoolQC': 'NoPool',
    'Fence': 'NoFence',
    'MiscFeature': 'None'
}

for col, placeholder in columns_with_na.items():
    train[col].fillna(placeholder, inplace=True)

# %%
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
data['LotFrontage_missing'] = train['LotFrontage'].isnull().astype(int)

# Impute missing LotFrontage with the median value of the same neighborhood
['LotFrontage'] = train.groupby('Neighborhood')['LotFrontage'].transform(
    lambda x: x.fillna(x.median()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 data['LotFrontage_missing'] = data['LotFrontage'].isnull().astype(int)
#       3 # Impute missing LotFrontage with the median value of the same neighborhood
#       4 data['LotFrontage'] = data.groupby('Neighborhood')['LotFrontage'].transform(
#       5     lambda x: x.fillna(x.median()))
#
# NameError: name 'data' is not defined

# %%
quality_mapping = {
    'Ex': 'Good',
    'Gd': 'Good',
    'TA': 'Average',
    'Fa': 'Poor',
    'Po': 'Poor',
    'NoGarage': 'NoGarage',
    'NoBasement': 'NoBasement',
    'NoPool': 'NoPool',
    'NoFence': 'NoFence'
}

for col in ['GarageQual', 'GarageCond', 'BsmtQual', 'BsmtCond', 'PoolQC', 'Fence']:
    if col in data.columns:
        data[col] = data[col].map(quality_mapping)

# Initialize the label encoder
label_enc = LabelEncoder()

# Apply label encoding to categorical features if they exist
categorical_cols = ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
                    'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
                    'BsmtFinType2', 'PoolQC', 'Fence', 'MiscFeature', 'Alley']

for col in categorical_cols:
    if col in data.columns:
        data[col] = label_enc.fit_transform(data[col])

# %%
columns_with_na['FireplaceQu'] = 'NoFireplace'

# Impute missing values in FireplaceQu
if 'FireplaceQu' in data.columns:
    data['FireplaceQu'].fillna('NoFireplace', inplace=True)

# %%
def bar_nanValue(x):                                                # Function to show missing values in the column to drop the column
    
    missing_percent = x.isnull().mean() * 100
    
    # Plotting the bar plot
    plt.figure(figsize=(15, 6))
    sns.barplot(x=missing_percent.index, y=missing_percent, color='skyblue')
    plt.axhline(y=40, color='r', linestyle='--')
    plt.title('Percentage of Missing Values by Column')
    plt.xticks(rotation=45, ha='right',fontsize=7)
    plt.xlabel('Columns')
    plt.ylabel('Percentage of Missing Values')
    plt.ylim(0, 100)  # Set limit to 100% for better visualization
    
    
    for i, value in enumerate(missing_percent):
        if value > 40:
            plt.text(i, value + 2, f'{value:.1f}%', ha='center', va='bottom', color='black')
    
    plt.show()

bar_nanValue(train)

# %%
def drop_col(x):                                              # Function for Dropping column which has more than 40% missing values
    threshold = 0.4
    missing_percent= x.isnull().mean() * 100
    
    # Drop columns with missing values above threshold
    columns_to_drop = missing_percent[missing_percent > threshold * 100].index
    x = x.drop(columns=columns_to_drop,inplace= True)
    
    print(f'Dropped columns: {columns_to_drop}')
    print(train.shape)

drop_col(train)
# Out:
# Dropped columns: Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')
# (1460, 76)

# %%
test= pd.read_csv('test.csv')
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
test.shape
# Out:
# (1459, 80)

# %%
bar_nanValue(test)

# %%
drop_col(test)
# Out:
# Dropped columns: Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')
# (1460, 76)

# %%
missing_values = train.isnull().sum()
missing_percentage = (train.isnull().sum() / train.shape[0]) * 100
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})
missing_data = missing_data[missing_data['Missing Values'] > 0].sort_values(by='Missing Values', ascending=False)
print(missing_data)
# Out:
#               Missing Values  Percentage
# LotFrontage              259   17.739726
# GarageType                81    5.547945
# GarageYrBlt               81    5.547945
# GarageFinish              81    5.547945
# GarageQual                81    5.547945
# GarageCond                81    5.547945
# BsmtExposure              38    2.602740
# BsmtFinType2              38    2.602740
# BsmtQual                  37    2.534247
# BsmtCond                  37    2.534247
# BsmtFinType1              37    2.534247
# MasVnrType                 8    0.547945
# MasVnrArea                 8    0.547945
# Electrical                 1    0.068493

# %%
def handle_missing(df):
    import missingno as msno
    # Create a DataFrame to store the correlation of missing values
    cols_with_missing = df.columns[df.isnull().any()]
    missing_corr = df[cols_with_missing].isnull().corr()
    
    # Step 2: Increase the Size of the Plot
    plt.figure(figsize=(15, 12))
    
    # Step 3: Annotate Only Significant Correlations and Mask the Lower Triangle
    mask = np.triu(np.ones_like(missing_corr, dtype=bool))
    sns.heatmap(missing_corr, annot=True, mask=mask, cmap='coolwarm', vmin=-1, vmax=1, annot_kws={"size": 8})
    plt.title("Correlation Matrix of Missing Values")
    plt.show()
    
    # Step 4: Use Clustering to Group Similar Columns
    msno.dendrogram(df)
    plt.show()
    
    sns.clustermap(missing_corr, annot=True, cmap='coolwarm', figsize=(15, 12), annot_kws={"size": 8})
    plt.title("Clustered Correlation Matrix of Missing Values")
    plt.show()

handle_missing(train)

# %%
# Example: Mean imputation for numerical columns
def missing_value(df):
    for col in df.select_dtypes(include='number').columns:
        df[col].fillna(df[col].mean(), inplace=True)
    
    # Example: Mode imputation for categorical columns
    for col in df.select_dtypes(include='object').columns:
        df[col].fillna(df[col].mode()[0], inplace=True)

# %%
missing_value(train)

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=train['MSSubClass'], y=train['SalePrice'],errorbar=None)
plt.xlabel('MSSubClass')
plt.ylabel('Mean Sales Price')
plt.title('Average Sales Price of Houses in MSSubClass')
plt.show()

# %% [markdown]
# ### * Where these numbers represented as:
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=train['MSZoning'], y=train['SalePrice'], errorbar=None)

plt.xlabel('MSZoning')
plt.ylabel('Mean Sales Price')
plt.title('Average Sales Price of Houses in MSZoning')
plt.show()

# %% [markdown]
# ### * MSZoning: Identifies the general zoning classification of the sale.
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(x=train['OverallQual'], y=train['SalePrice'], alpha=0.6)

sns.lineplot(x='OverallQual', y='SalePrice', data=train, errorbar=None, estimator='mean', color='red')

plt.title('Relationship between Overall Quality and Sale Price')
plt.xlabel('Overall Quality')
plt.ylabel('Sale Price in Dollar')
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
sns.barplot(x=train['Street'], y=train['SalePrice'], errorbar=None)

# sns.lineplot(x='OverallQual', y='SalePrice', data=train, errorbar=None, estimator='mean', color='red')

plt.title('Average Sales Price of House with type of Street')
plt.xlabel('Street')
plt.ylabel('Sale Price in Dollar')

plt.subplot(1,2,2)
sns.barplot(x= train['LotShape'], y= train['SalePrice'], errorbar= None)
plt.title('Average Sales Price of House with type of LotShape')
plt.xlabel('LotShape')
plt.ylabel('Sale Price in Dollar')

plt.tight_layout()
plt.show()

# %% [markdown]
# <p style='text-align: justify;'> <b>Street:</b> Type of road access to property
#        <br>Grvl	   Gravel
#        <br>Pave	   Paved
#        	 </p>
# <p style='text-align: right;'>  <b>LotShape:</b> General shape of property <br>Reg	Regular <br>IR1	Slightly irregular  <br>IR2	Moderately Irregular   <br>IR3	Irregular </p>

# %%
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... Condition1_RRAn Condition1_RRNe Condition1_RRNn  \
# 0    AllPub    Inside  ...               0               0               0
# 1    AllPub       FR2  ...               0               0               0
# 2    AllPub    Inside  ...               0               0               0
# 3    AllPub    Corner  ...               0               0               0
# 4    AllPub       FR2  ...               0               0               0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\python38\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\python38\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\python38\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Condition1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
